# %%
import ROOT as root
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
# Out:
# Welcome to JupyROOT 6.24/06

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_6001.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/AnaBarMC_Gen_6001.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_6001.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 3.77544
#  Y_vtx           = 5
#  Z_vtx           = -4.69629
#  Px_p            = -874.616
#  Py_p            = -3251.39
#  Pz_p            = 394.069
#  En_p            = 3389.95
#  Mass            = 0.510999
#  PDG             = 11

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_7001.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/AnaBarMC_Gen_7001.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_7001.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = -3.58584
#  Y_vtx           = 5
#  Z_vtx           = -6.49094
#  Px_p            = -268.008
#  Py_p            = -996.321
#  Pz_p            = 120.754
#  En_p            = 1044.14
#  Mass            = 105.658
#  PDG             = 13

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_8001.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/AnaBarMC_Gen_8001.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_8001.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = -2.63671
#  Y_vtx           = 5
#  Z_vtx           = -1.29456
#  Px_p            = -1265.92
#  Py_p            = -4706.05
#  Pz_p            = 570.375
#  En_p            = 4995.76
#  Mass            = 939.565
#  PDG             = 2112

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_9001.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/AnaBarMC_Gen_9001.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_9001.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 3.74344
#  Y_vtx           = 5
#  Z_vtx           = -2.20249
#  Px_p            = -799.757
#  Py_p            = -2973.1
#  Pz_p            = 360.341
#  En_p            = 3238.69
#  Mass            = 938.272
#  PDG             = 2212
