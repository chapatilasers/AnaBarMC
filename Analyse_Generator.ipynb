# %%
import ROOT as root
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
f = root.TFile("batch/data/new.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(1)
myTree.Print()
# Out:
# TFile**		batch/data/new.root
#  TFile*		batch/data/new.root
#   KEY: TTree	h1;1
# ======> EVENT:1
#  X_vtx           = -7.00707
#  Y_vtx           = -325.804
#  Z_vtx           = 206.257
#  Px_p            = -74.0265
#  Py_p            = -3207.81
#  Pz_p            = 2072.47
#  En_p            = 3819.78
#  Mass            = 0.510999
#  PDG             = 11
# ******************************************************************************
# *Tree    :h1        :                                                        *
# *Entries :      632 : Total =           48416 bytes  File  Size =      20931 *
# *        :          : Tree compression factor =   2.72                       *
# ******************************************************************************
# *Br    0 :X_vtx     : X_vtx/D                                                *
# *Entries :      632 : Total  Size=       5623 bytes  File Size  =       2260 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br    1 :Y_vtx     : Y_vtx/D                                                *
# *Entries :      632 : Total  Size=       5623 bytes  File Size  =       2232 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br    2 :Z_vtx     : Z_vtx/D                                                *
# *Entries :      632 : Total  Size=       5623 bytes  File Size  =       2209 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.32     *
# *............................................................................*
# *Br    3 :Px_p      : Px_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2257 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br    4 :Py_p      : Py_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2214 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.31     *
# *............................................................................*
# *Br    5 :Pz_p      : Pz_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2250 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.28     *
# *............................................................................*
# *Br    6 :En_p      : En_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2226 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br    7 :Mass      : Mass/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =        203 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  25.25     *
# *............................................................................*
# *Br    8 :PDG       : PDG/I                                                  *
# *Entries :      632 : Total  Size=       3077 bytes  File Size  =        186 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  13.96     *
# *............................................................................*

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_7000.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
myTree.Print()
# Out:
# TFile**		batch/data/AnaBarMC_Gen_7000.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_7000.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 126.302
#  Y_vtx           = -331.936
#  Z_vtx           = 195.194
#  Px_p            = 1097.28
#  Py_p            = -2851.25
#  Pz_p            = 1699.05
#  En_p            = 3495.77
#  Mass            = 0.510999
#  PDG             = 11
# ******************************************************************************
# *Tree    :h1        : Generator Output Tree                                  *
# *Entries :      100 : Total =            9010 bytes  File  Size =       3526 *
# *        :          : Tree compression factor =   1.57                       *
# ******************************************************************************
# *Br    0 :X_vtx     : X_vtx/F                                                *
# *Entries :      100 : Total  Size=        959 bytes  File Size  =        365 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.29     *
# *............................................................................*
# *Br    1 :Y_vtx     : Y_vtx/F                                                *
# *Entries :      100 : Total  Size=        959 bytes  File Size  =        351 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.34     *
# *............................................................................*
# *Br    2 :Z_vtx     : Z_vtx/F                                                *
# *Entries :      100 : Total  Size=        959 bytes  File Size  =        345 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.36     *
# *............................................................................*
# *Br    3 :Px_p      : Px_p/F                                                 *
# *Entries :      100 : Total  Size=        954 bytes  File Size  =        361 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.30     *
# *............................................................................*
# *Br    4 :Py_p      : Py_p/F                                                 *
# *Entries :      100 : Total  Size=        954 bytes  File Size  =        350 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.34     *
# *............................................................................*
# *Br    5 :Pz_p      : Pz_p/F                                                 *
# *Entries :      100 : Total  Size=        954 bytes  File Size  =        355 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.32     *
# *............................................................................*
# *Br    6 :En_p      : En_p/F                                                 *
# *Entries :      100 : Total  Size=        954 bytes  File Size  =        345 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.36     *
# *............................................................................*
# *Br    7 :Mass      : Mass/F                                                 *
# *Entries :      100 : Total  Size=        954 bytes  File Size  =        108 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   4.34     *
# *............................................................................*
# *Br    8 :PDG       : PDG/I                                                  *
# *Entries :      100 : Total  Size=        949 bytes  File Size  =        116 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   4.03     *
# *............................................................................*

# %%
f = root.TFile("batch/data/gep_12Gev100.root")
f.ls()

myTree = f.Get("T")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/gep_12Gev100.root
#  TFile*		batch/data/gep_12Gev100.root
#   KEY: TTree	T;1	Geant4 SBS Simulation
#   KEY: TH1F	Earm_CDET_Scint_esum;1
#   KEY: TH1F	Earm_ECalTF1_esum;1
#   KEY: TH1F	Harm_HCalScint_esum;1
#   KEY: TH1F	Earm_CDET_Scint_pulseshape;1
#   KEY: TH1F	Earm_ECalTF1_pulseshape;1
#   KEY: TH1F	Harm_HCalScint_pulseshape;1
#   KEY: G4SBSRunData	run_data;1
#   KEY: TH2F	field_x;1	Field x component
#   KEY: TH2F	field_y;1	Field y component
#   KEY: TH2F	field_z;1	Field z component
#   KEY: TH2F	field;1	Field total magnitude
#   KEY: TH2F	hBx_yzproj_Earm;1	Bx, Earm yz projection
#   KEY: TH2F	hBy_yzproj_Earm;1	By, Earm yz projection
#   KEY: TH2F	hBz_yzproj_Earm;1	Bz, Earm yz projection
#   KEY: TH2F	hBtot_yzproj_Earm;1	|B|, Earm yz projection
#   KEY: TH2F	hBx_yzproj_Harm;1	Bx, Harm yz projection
#   KEY: TH2F	hBy_yzproj_Harm;1	By, Harm yz projection
#   KEY: TH2F	hBz_yzproj_Harm;1	Bz, Harm yz projection
#   KEY: TH2F	hBtot_yzproj_Harm;1	|B|, Harm yz projection
# ======> EVENT:50
#  count           = 0.121122
#  rate            = 0.121122
#  solang          = 0.293866
#  sigma           = 6.91876e-38
#  W2              = 0.880354
#  xbj             = 1
#  Q2              = 14.0779
#  th              = 0.614495
#  ph              = -0.577639
#  Aperp           = -0.00160585
#  Apar            = -0.86693
#  Pt              = -0.00160585
#  Pl              = 0.86693
#  vx              = 0.00107739
#  vy              = 0.00196676
#  vz              = 0.0389065
#  ep              = 3.49798
#  np              = 8.38798
#  epx             = 1.68954
#  epy             = -1.10124
#  epz             = 2.85808
#  npx             = -1.68954
#  npy             = 1.10124
#  npz             = 8.14192
#  nth             = 0.242812
#  nph             = 2.56395
#  pmperp          = 0
#  pmpar           = 0
#  pmparsm         = -nan
#  z               = 0
#  phperp          = 0
#  phih            = 0
#  phiS            = 0
#  thetaS          = 0
#  MX2             = 0
#  Sx              = -0.114668
#  Sy              = 0.076185
#  Sz              = 0.855931
#  s               = 0
#  t               = 0
#  u               = 0
#  costhetaCM      = 0
#  Egamma          = 0
#  nucl            = 1
#  fnucl           = 1
#  hadr            = -21228832
#  earmaccept      = 0
#  harmaccept      = 0
#  TargPol         = 1
#  TargThetaSpin   = 0
#  TargPhiSpin     = 0
#  BeamPol         = 1
#  BeamThetaSpin   = 0
#  BeamPhiSpin     = 0
#  Earm.CDET_Scint.det.esum = 0.0143518
#  Earm.CDET_Scint.hit.nhits = 2
#  Earm.CDET_Scint.hit.row = (vector<int>*)0x8196920
#  Earm.CDET_Scint.hit.col = (vector<int>*)0x9fc18a0
#  Earm.CDET_Scint.hit.cell = (vector<int>*)0x9f9adf0
#  Earm.CDET_Scint.hit.plane = (vector<int>*)0x828ab40
#  Earm.CDET_Scint.hit.wire = (vector<int>*)0x8363f80
#  Earm.CDET_Scint.hit.xcell = (vector<double>*)0x82e92b0
#  Earm.CDET_Scint.hit.ycell = (vector<double>*)0x8364500
#  Earm.CDET_Scint.hit.zcell = (vector<double>*)0x8364a80
#  Earm.CDET_Scint.hit.xcellg = (vector<double>*)0x8365120
#  Earm.CDET_Scint.hit.ycellg = (vector<double>*)0x8365760
#  Earm.CDET_Scint.hit.zcellg = (vector<double>*)0x8365e00
#  Earm.CDET_Scint.hit.xhit = (vector<double>*)0x8366380
#  Earm.CDET_Scint.hit.yhit = (vector<double>*)0x8366a20
#  Earm.CDET_Scint.hit.zhit = (vector<double>*)0x8367060
#  Earm.CDET_Scint.hit.xhitg = (vector<double>*)0x8367700
#  Earm.CDET_Scint.hit.yhitg = (vector<double>*)0x8367c80
#  Earm.CDET_Scint.hit.zhitg = (vector<double>*)0x8368980
#  Earm.CDET_Scint.hit.sumedep = (vector<double>*)0x8368420
#  Earm.CDET_Scint.hit.tavg = (vector<double>*)0x83fed40
#  Earm.CDET_Scint.hit.trms = (vector<double>*)0x84070c0
#  Earm.CDET_Scint.hit.tmin = (vector<double>*)0x840f470
#  Earm.CDET_Scint.hit.tmax = (vector<double>*)0x8417700
#  Earm.CDET_Scint.hit.otridx = (vector<int>*)0x841fab0
#  Earm.CDET_Scint.hit.ptridx = (vector<int>*)0x8427e00
#  Earm.CDET_Scint.hit.sdtridx = (vector<int>*)0x84301b0
#  Earm.ECalTF1.det.esum = 0
#  Earm.ECalTF1.hit.nhits = 0
#  Earm.ECalTF1.hit.row = (vector<int>*)0x8448480
#  Earm.ECalTF1.hit.col = (vector<int>*)0x84506f0
#  Earm.ECalTF1.hit.cell = (vector<int>*)0x8458a80
#  Earm.ECalTF1.hit.plane = (vector<int>*)0x8458d50
#  Earm.ECalTF1.hit.wire = (vector<int>*)0x8469080
#  Earm.ECalTF1.hit.xcell = (vector<double>*)0x8471410
#  Earm.ECalTF1.hit.ycell = (vector<double>*)0x84716e0
#  Earm.ECalTF1.hit.zcell = (vector<double>*)0x8481a10
#  Earm.ECalTF1.hit.xcellg = (vector<double>*)0x8489da0
#  Earm.ECalTF1.hit.ycellg = (vector<double>*)0x848a070
#  Earm.ECalTF1.hit.zcellg = (vector<double>*)0x849a3a0
#  Earm.ECalTF1.hit.xhit = (vector<double>*)0x84a2730
#  Earm.ECalTF1.hit.yhit = (vector<double>*)0x84a2a00
#  Earm.ECalTF1.hit.zhit = (vector<double>*)0x84b2d30
#  Earm.ECalTF1.hit.xhitg = (vector<double>*)0x84bb0c0
#  Earm.ECalTF1.hit.yhitg = (vector<double>*)0x84bb390
#  Earm.ECalTF1.hit.zhitg = (vector<double>*)0x84cb6c0
#  Earm.ECalTF1.hit.sumedep = (vector<double>*)0x84d3a50
#  Earm.ECalTF1.hit.tavg = (vector<double>*)0x84d3d20
#  Earm.ECalTF1.hit.trms = (vector<double>*)0x84e4050
#  Earm.ECalTF1.hit.tmin = (vector<double>*)0x84ec3e0
#  Earm.ECalTF1.hit.tmax = (vector<double>*)0x84ec6b0
#  Earm.ECalTF1.hit.otridx = (vector<int>*)0x84fc9e0
#  Earm.ECalTF1.hit.ptridx = (vector<int>*)0x8504d70
#  Earm.ECalTF1.hit.sdtridx = (vector<int>*)0x8505040
#  Harm.FPP1.hit.nhits = 0
#  Harm.FPP1.hit.plane = (vector<int>*)0x851d3f0
#  Harm.FPP1.hit.strip = (vector<int>*)0x8525660
#  Harm.FPP1.hit.x = (vector<double>*)0x852d9f0
#  Harm.FPP1.hit.y = (vector<double>*)0x8535d70
#  Harm.FPP1.hit.z = (vector<double>*)0x853dfb0
#  Harm.FPP1.hit.polx = (vector<double>*)0x8546390
#  Harm.FPP1.hit.poly = (vector<double>*)0x854e600
#  Harm.FPP1.hit.polz = (vector<double>*)0x8556990
#  Harm.FPP1.hit.t = (vector<double>*)0x8556c60
#  Harm.FPP1.hit.trms = (vector<double>*)0x8566f60
#  Harm.FPP1.hit.tmin = (vector<double>*)0x856f370
#  Harm.FPP1.hit.tmax = (vector<double>*)0x85775e0
#  Harm.FPP1.hit.tx = (vector<double>*)0x857f970
#  Harm.FPP1.hit.ty = (vector<double>*)0x857fc40
#  Harm.FPP1.hit.xin = (vector<double>*)0x858ff70
#  Harm.FPP1.hit.yin = (vector<double>*)0x8598300
#  Harm.FPP1.hit.zin = (vector<double>*)0x85985d0
#  Harm.FPP1.hit.xout = (vector<double>*)0x85a8900
#  Harm.FPP1.hit.yout = (vector<double>*)0x85b0c90
#  Harm.FPP1.hit.zout = (vector<double>*)0x85b0f60
#  Harm.FPP1.hit.txp = (vector<double>*)0x85c1290
#  Harm.FPP1.hit.typ = (vector<double>*)0x85c9620
#  Harm.FPP1.hit.xg = (vector<double>*)0x85c98f0
#  Harm.FPP1.hit.yg = (vector<double>*)0x85d9c20
#  Harm.FPP1.hit.zg = (vector<double>*)0x85e1fb0
#  Harm.FPP1.hit.trid = (vector<int>*)0x85e2280
#  Harm.FPP1.hit.mid = (vector<int>*)0x85f25b0
#  Harm.FPP1.hit.pid = (vector<int>*)0x85fa940
#  Harm.FPP1.hit.vx = (vector<double>*)0x85fac10
#  Harm.FPP1.hit.vy = (vector<double>*)0x860af40
#  Harm.FPP1.hit.vz = (vector<double>*)0x86132d0
#  Harm.FPP1.hit.p = (vector<double>*)0x86135a0
#  Harm.FPP1.hit.edep = (vector<double>*)0x86238a0
#  Harm.FPP1.hit.beta = (vector<double>*)0x862bcb0
#  Harm.FPP1.hit.otridx = (vector<int>*)0x8633f20
#  Harm.FPP1.hit.ptridx = (vector<int>*)0x863c2b0
#  Harm.FPP1.hit.sdtridx = (vector<int>*)0x863c580
#  Harm.FPP1.Track.ntracks = 0
#  Harm.FPP1.Track.TID = (vector<int>*)0x8654930
#  Harm.FPP1.Track.PID = (vector<int>*)0x865cba0
#  Harm.FPP1.Track.MID = (vector<int>*)0x8664f30
#  Harm.FPP1.Track.NumHits = (vector<int>*)0x8665200
#  Harm.FPP1.Track.NumPlanes = (vector<int>*)0x8675530
#  Harm.FPP1.Track.NDF = (vector<int>*)0x867d8c0
#  Harm.FPP1.Track.Chi2fit = (vector<double>*)0x867db90
#  Harm.FPP1.Track.Chi2true = (vector<double>*)0x868dec0
#  Harm.FPP1.Track.X = (vector<double>*)0x8696250
#  Harm.FPP1.Track.Y = (vector<double>*)0x8696520
#  Harm.FPP1.Track.Xp = (vector<double>*)0x86a6850
#  Harm.FPP1.Track.Yp = (vector<double>*)0x86aebe0
#  Harm.FPP1.Track.T = (vector<double>*)0x86aeeb0
#  Harm.FPP1.Track.P = (vector<double>*)0x86bf1e0
#  Harm.FPP1.Track.Sx = (vector<double>*)0x86c7570
#  Harm.FPP1.Track.Sy = (vector<double>*)0x86c7840
#  Harm.FPP1.Track.Sz = (vector<double>*)0x86d7b70
#  Harm.FPP1.Track.Xfit = (vector<double>*)0x86dff00
#  Harm.FPP1.Track.Yfit = (vector<double>*)0x86e01d0
#  Harm.FPP1.Track.Xpfit = (vector<double>*)0x86f0500
#  Harm.FPP1.Track.Ypfit = (vector<double>*)0x86f8890
#  Harm.FPP1.Track.otridx = (vector<int>*)0x86f8b60
#  Harm.FPP1.Track.ptridx = (vector<int>*)0x8708e90
#  Harm.FPP1.Track.sdtridx = (vector<int>*)0x8711220
#  Harm.FPP2.hit.nhits = 0
#  Harm.FPP2.hit.plane = (vector<int>*)0x87114f0
#  Harm.FPP2.hit.strip = (vector<int>*)0x87297e0
#  Harm.FPP2.hit.x = (vector<double>*)0x8731b70
#  Harm.FPP2.hit.y = (vector<double>*)0x8739ef0
#  Harm.FPP2.hit.z = (vector<double>*)0x8742130
#  Harm.FPP2.hit.polx = (vector<double>*)0x874a510
#  Harm.FPP2.hit.poly = (vector<double>*)0x8752780
#  Harm.FPP2.hit.polz = (vector<double>*)0x875ab10
#  Harm.FPP2.hit.t = (vector<double>*)0x875ade0
#  Harm.FPP2.hit.trms = (vector<double>*)0x876b0e0
#  Harm.FPP2.hit.tmin = (vector<double>*)0x87734f0
#  Harm.FPP2.hit.tmax = (vector<double>*)0x877b760
#  Harm.FPP2.hit.tx = (vector<double>*)0x8783af0
#  Harm.FPP2.hit.ty = (vector<double>*)0x8783dc0
#  Harm.FPP2.hit.xin = (vector<double>*)0x87940f0
#  Harm.FPP2.hit.yin = (vector<double>*)0x879c480
#  Harm.FPP2.hit.zin = (vector<double>*)0x879c750
#  Harm.FPP2.hit.xout = (vector<double>*)0x87aca80
#  Harm.FPP2.hit.yout = (vector<double>*)0x87b4e10
#  Harm.FPP2.hit.zout = (vector<double>*)0x87b50e0
#  Harm.FPP2.hit.txp = (vector<double>*)0x87c5410
#  Harm.FPP2.hit.typ = (vector<double>*)0x87cd7a0
#  Harm.FPP2.hit.xg = (vector<double>*)0x87cda70
#  Harm.FPP2.hit.yg = (vector<double>*)0x87ddda0
#  Harm.FPP2.hit.zg = (vector<double>*)0x87e6130
#  Harm.FPP2.hit.trid = (vector<int>*)0x87e6400
#  Harm.FPP2.hit.mid = (vector<int>*)0x87f6730
#  Harm.FPP2.hit.pid = (vector<int>*)0x87feac0
#  Harm.FPP2.hit.vx = (vector<double>*)0x87fed90
#  Harm.FPP2.hit.vy = (vector<double>*)0x880f0c0
#  Harm.FPP2.hit.vz = (vector<double>*)0x8817450
#  Harm.FPP2.hit.p = (vector<double>*)0x8817720
#  Harm.FPP2.hit.edep = (vector<double>*)0x8827a20
#  Harm.FPP2.hit.beta = (vector<double>*)0x882fe30
#  Harm.FPP2.hit.otridx = (vector<int>*)0x88380a0
#  Harm.FPP2.hit.ptridx = (vector<int>*)0x8840430
#  Harm.FPP2.hit.sdtridx = (vector<int>*)0x8840700
#  Harm.FPP2.Track.ntracks = 0
#  Harm.FPP2.Track.TID = (vector<int>*)0x8858ab0
#  Harm.FPP2.Track.PID = (vector<int>*)0x8860d20
#  Harm.FPP2.Track.MID = (vector<int>*)0x88690b0
#  Harm.FPP2.Track.NumHits = (vector<int>*)0x8869380
#  Harm.FPP2.Track.NumPlanes = (vector<int>*)0x88796b0
#  Harm.FPP2.Track.NDF = (vector<int>*)0x8881a40
#  Harm.FPP2.Track.Chi2fit = (vector<double>*)0x8881d10
#  Harm.FPP2.Track.Chi2true = (vector<double>*)0x8892040
#  Harm.FPP2.Track.X = (vector<double>*)0x889a3d0
#  Harm.FPP2.Track.Y = (vector<double>*)0x889a6a0
#  Harm.FPP2.Track.Xp = (vector<double>*)0x88aa9d0
#  Harm.FPP2.Track.Yp = (vector<double>*)0x88b2d60
#  Harm.FPP2.Track.T = (vector<double>*)0x88b3030
#  Harm.FPP2.Track.P = (vector<double>*)0x88c3360
#  Harm.FPP2.Track.Sx = (vector<double>*)0x88cb6f0
#  Harm.FPP2.Track.Sy = (vector<double>*)0x88cb9c0
#  Harm.FPP2.Track.Sz = (vector<double>*)0x88dbcf0
#  Harm.FPP2.Track.Xfit = (vector<double>*)0x88e4080
#  Harm.FPP2.Track.Yfit = (vector<double>*)0x88e4350
#  Harm.FPP2.Track.Xpfit = (vector<double>*)0x88f4680
#  Harm.FPP2.Track.Ypfit = (vector<double>*)0x88fca10
#  Harm.FPP2.Track.otridx = (vector<int>*)0x88fcce0
#  Harm.FPP2.Track.ptridx = (vector<int>*)0x890d010
#  Harm.FPP2.Track.sdtridx = (vector<int>*)0x89153a0
#  Harm.FT.hit.nhits = 0
#  Harm.FT.hit.plane = (vector<int>*)0x8915670
#  Harm.FT.hit.strip = (vector<int>*)0x892d960
#  Harm.FT.hit.x   = (vector<double>*)0x8935cf0
#  Harm.FT.hit.y   = (vector<double>*)0x893e020
#  Harm.FT.hit.z   = (vector<double>*)0x8946260
#  Harm.FT.hit.polx = (vector<double>*)0x894e5c0
#  Harm.FT.hit.poly = (vector<double>*)0x8956830
#  Harm.FT.hit.polz = (vector<double>*)0x895ebc0
#  Harm.FT.hit.t   = (vector<double>*)0x895ee90
#  Harm.FT.hit.trms = (vector<double>*)0x896f190
#  Harm.FT.hit.tmin = (vector<double>*)0x89774f0
#  Harm.FT.hit.tmax = (vector<double>*)0x89777c0
#  Harm.FT.hit.tx  = (vector<double>*)0x8987af0
#  Harm.FT.hit.ty  = (vector<double>*)0x898fe80
#  Harm.FT.hit.xin = (vector<double>*)0x89980c0
#  Harm.FT.hit.yin = (vector<double>*)0x89a0430
#  Harm.FT.hit.zin = (vector<double>*)0x89a87c0
#  Harm.FT.hit.xout = (vector<double>*)0x89b0a00
#  Harm.FT.hit.yout = (vector<double>*)0x89b8dc0
#  Harm.FT.hit.zout = (vector<double>*)0x89c1030
#  Harm.FT.hit.txp = (vector<double>*)0x89c93c0
#  Harm.FT.hit.typ = (vector<double>*)0x89d1740
#  Harm.FT.hit.xg  = (vector<double>*)0x89d9980
#  Harm.FT.hit.yg  = (vector<double>*)0x89e1d90
#  Harm.FT.hit.zg  = (vector<double>*)0x89e9f90
#  Harm.FT.hit.trid = (vector<int>*)0x89f22c0
#  Harm.FT.hit.mid = (vector<int>*)0x89fa530
#  Harm.FT.hit.pid = (vector<int>*)0x8a028d0
#  Harm.FT.hit.vx  = (vector<double>*)0x8a0ac60
#  Harm.FT.hit.vy  = (vector<double>*)0x8a02b90
#  Harm.FT.hit.vz  = (vector<double>*)0x8a1b210
#  Harm.FT.hit.p   = (vector<double>*)0x8a23420
#  Harm.FT.hit.edep = (vector<double>*)0x8a2b7c0
#  Harm.FT.hit.beta = (vector<double>*)0x8a33a30
#  Harm.FT.hit.otridx = (vector<int>*)0x8a3bd60
#  Harm.FT.hit.ptridx = (vector<int>*)0x8a3c030
#  Harm.FT.hit.sdtridx = (vector<int>*)0x8a4c360
#  Harm.FT.Track.ntracks = 0
#  Harm.FT.Track.TID = (vector<int>*)0x8a549b0
#  Harm.FT.Track.PID = (vector<int>*)0x8a649a0
#  Harm.FT.Track.MID = (vector<int>*)0x8a6cd30
#  Harm.FT.Track.NumHits = (vector<int>*)0x8a6d000
#  Harm.FT.Track.NumPlanes = (vector<int>*)0x8a7d330
#  Harm.FT.Track.NDF = (vector<int>*)0x8a856c0
#  Harm.FT.Track.Chi2fit = (vector<double>*)0x8a85990
#  Harm.FT.Track.Chi2true = (vector<double>*)0x8a95cc0
#  Harm.FT.Track.X = (vector<double>*)0x8a9e050
#  Harm.FT.Track.Y = (vector<double>*)0x8aa63d0
#  Harm.FT.Track.Xp = (vector<double>*)0x8aae610
#  Harm.FT.Track.Yp = (vector<double>*)0x8ab6a20
#  Harm.FT.Track.T = (vector<double>*)0x8abec90
#  Harm.FT.Track.P = (vector<double>*)0x8ac7030
#  Harm.FT.Track.Sx = (vector<double>*)0x8acf3c0
#  Harm.FT.Track.Sy = (vector<double>*)0x8ac72f0
#  Harm.FT.Track.Sz = (vector<double>*)0x8adf9d0
#  Harm.FT.Track.Xfit = (vector<double>*)0x8ae7c40
#  Harm.FT.Track.Yfit = (vector<double>*)0x8aeffd0
#  Harm.FT.Track.Xpfit = (vector<double>*)0x8af02a0
#  Harm.FT.Track.Ypfit = (vector<double>*)0x8b005d0
#  Harm.FT.Track.otridx = (vector<int>*)0x8b08960
#  Harm.FT.Track.ptridx = (vector<int>*)0x8b08c30
#  Harm.FT.Track.sdtridx = (vector<int>*)0x8b18f60
#  Harm.HCalScint.det.esum = 0
#  Harm.HCalScint.hit.nhits = 0
#  Harm.HCalScint.hit.row = (vector<int>*)0x8b312e0
#  Harm.HCalScint.hit.col = (vector<int>*)0x8b39550
#  Harm.HCalScint.hit.cell = (vector<int>*)0x8b418e0
#  Harm.HCalScint.hit.plane = (vector<int>*)0x8b41bb0
#  Harm.HCalScint.hit.wire = (vector<int>*)0x8b51ee0
#  Harm.HCalScint.hit.xcell = (vector<double>*)0x8b5a270
#  Harm.HCalScint.hit.ycell = (vector<double>*)0x8b5a520
#  Harm.HCalScint.hit.zcell = (vector<double>*)0x8b5a540
#  Harm.HCalScint.hit.xcellg = (vector<double>*)0x8b72ae0
#  Harm.HCalScint.hit.ycellg = (vector<double>*)0x8b7ad90
#  Harm.HCalScint.hit.zcellg = (vector<double>*)0x8b83040
#  Harm.HCalScint.hit.xhit = (vector<double>*)0x8b8b2f0
#  Harm.HCalScint.hit.yhit = (vector<double>*)0x8b935a0
#  Harm.HCalScint.hit.zhit = (vector<double>*)0x8b9b850
#  Harm.HCalScint.hit.xhitg = (vector<double>*)0x8ba3b00
#  Harm.HCalScint.hit.yhitg = (vector<double>*)0x8babdb0
#  Harm.HCalScint.hit.zhitg = (vector<double>*)0x8bb4060
#  Harm.HCalScint.hit.sumedep = (vector<double>*)0x8bbc310
#  Harm.HCalScint.hit.tavg = (vector<double>*)0x8bc45c0
#  Harm.HCalScint.hit.trms = (vector<double>*)0x8bcc870
#  Harm.HCalScint.hit.tmin = (vector<double>*)0x8bd4b20
#  Harm.HCalScint.hit.tmax = (vector<double>*)0x8bdcdd0
#  Harm.HCalScint.hit.otridx = (vector<int>*)0x8be5080
#  Harm.HCalScint.hit.ptridx = (vector<int>*)0x8bed2f0
#  Harm.HCalScint.hit.sdtridx = (vector<int>*)0x8bf5680
#  OTrack.ntracks  = 1
#  OTrack.TID      = (vector<int>*)0x8bf5950
#  OTrack.MID      = (vector<int>*)0x8c0dbd0
#  OTrack.PID      = (vector<int>*)0x8c15f50
#  OTrack.posx     = (vector<double>*)0x8c1e1b0
#  OTrack.posy     = (vector<double>*)0x8c26530
#  OTrack.posz     = (vector<double>*)0x8c2e790
#  OTrack.momx     = (vector<double>*)0x8c36b10
#  OTrack.momy     = (vector<double>*)0x8c3ed70
#  OTrack.momz     = (vector<double>*)0x8c470f0
#  OTrack.polx     = (vector<double>*)0x8c4f350
#  OTrack.poly     = (vector<double>*)0x8c576d0
#  OTrack.polz     = (vector<double>*)0x8c5f930
#  OTrack.Etot     = (vector<double>*)0x8c67cb0
#  OTrack.T        = (vector<double>*)0x8c6ff10
#  PTrack.ntracks  = 1
#  PTrack.TID      = (vector<int>*)0x8c801f0
#  PTrack.PID      = (vector<int>*)0x8c88450
#  PTrack.posx     = (vector<double>*)0x8c907d0
#  PTrack.posy     = (vector<double>*)0x8c98a30
#  PTrack.posz     = (vector<double>*)0x8ca0db0
#  PTrack.momx     = (vector<double>*)0x8ca9010
#  PTrack.momy     = (vector<double>*)0x8cb1390
#  PTrack.momz     = (vector<double>*)0x8cb95f0
#  PTrack.polx     = (vector<double>*)0x8cc1970
#  PTrack.poly     = (vector<double>*)0x8cc9bd0
#  PTrack.polz     = (vector<double>*)0x8cd1f50
#  PTrack.Etot     = (vector<double>*)0x8cda1b0
#  PTrack.T        = (vector<double>*)0x8ce2530
#  SDTrack.ntracks = 1
#  SDTrack.TID     = (vector<int>*)0x8cf27c0
#  SDTrack.MID     = (vector<int>*)0x8cfaa20
#  SDTrack.PID     = (vector<int>*)0x8d02da0
#  SDTrack.posx    = (vector<double>*)0x8d0b000
#  SDTrack.posy    = (vector<double>*)0x8d13380
#  SDTrack.posz    = (vector<double>*)0x8d1b5e0
#  SDTrack.momx    = (vector<double>*)0x8d23960
#  SDTrack.momy    = (vector<double>*)0x8d2bbc0
#  SDTrack.momz    = (vector<double>*)0x8d33f40
#  SDTrack.polx    = (vector<double>*)0x8d3c1a0
#  SDTrack.poly    = (vector<double>*)0x8d44520
#  SDTrack.polz    = (vector<double>*)0x8d4c780
#  SDTrack.Etot    = (vector<double>*)0x8d54b00
#  SDTrack.T       = (vector<double>*)0x8d5cd60
#  SDTrack.vx      = (vector<double>*)0x8d650e0
#  SDTrack.vy      = (vector<double>*)0x8d6d340
#  SDTrack.vz      = (vector<double>*)0x8d756c0
#  SDTrack.vnx     = (vector<double>*)0x8d7d920
#  SDTrack.vny     = (vector<double>*)0x8d85ca0
#  SDTrack.vnz     = (vector<double>*)0x8d8df00
#  SDTrack.vEkin   = (vector<double>*)0x8d96280

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_7004.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/AnaBarMC_Gen_7004.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_7004.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 1.20794
#  Y_vtx           = 25
#  Z_vtx           = -7.44103
#  Px_p            = 64.5141
#  Py_p            = -2987.89
#  Pz_p            = 445.626
#  En_p            = 3023.48
#  Mass            = 105.658
#  PDG             = 13

# %%
# Out:
# TFile**		batch/data/AnaBarMC_Gen_9001.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_9001.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 3.74344
#  Y_vtx           = 5
#  Z_vtx           = -2.20249
#  Px_p            = -799.757
#  Py_p            = -2973.1
#  Pz_p            = 360.341
#  En_p            = 3238.69
#  Mass            = 938.272
#  PDG             = 2212
