# %%
import ROOT as root
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
# Out:
# Welcome to JupyROOT 6.24/08

# %%
f = root.TFile("batch/data/new.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(1)
myTree.Print()
# Out:
# TFile**		batch/data/new.root
#  TFile*		batch/data/new.root
#   KEY: TTree	h1;1
# ======> EVENT:1
#  X_vtx           = -7.00707
#  Y_vtx           = -325.804
#  Z_vtx           = 206.257
#  Px_p            = -74.0265
#  Py_p            = -3207.81
#  Pz_p            = 2072.47
#  En_p            = 3819.78
#  Mass            = 0.510999
#  PDG             = 11
# ******************************************************************************
# *Tree    :h1        :                                                        *
# *Entries :      632 : Total =           48416 bytes  File  Size =      20931 *
# *        :          : Tree compression factor =   2.72                       *
# ******************************************************************************
# *Br    0 :X_vtx     : X_vtx/D                                                *
# *Entries :      632 : Total  Size=       5623 bytes  File Size  =       2260 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br    1 :Y_vtx     : Y_vtx/D                                                *
# *Entries :      632 : Total  Size=       5623 bytes  File Size  =       2232 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br    2 :Z_vtx     : Z_vtx/D                                                *
# *Entries :      632 : Total  Size=       5623 bytes  File Size  =       2209 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.32     *
# *............................................................................*
# *Br    3 :Px_p      : Px_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2257 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br    4 :Py_p      : Py_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2214 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.31     *
# *............................................................................*
# *Br    5 :Pz_p      : Pz_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2250 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.28     *
# *............................................................................*
# *Br    6 :En_p      : En_p/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =       2226 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br    7 :Mass      : Mass/D                                                 *
# *Entries :      632 : Total  Size=       5618 bytes  File Size  =        203 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  25.25     *
# *............................................................................*
# *Br    8 :PDG       : PDG/I                                                  *
# *Entries :      632 : Total  Size=       3077 bytes  File Size  =        186 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  13.96     *
# *............................................................................*

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_7000.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
myTree.Print()
# Out:
# TFile**		batch/data/AnaBarMC_Gen_7000.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_7000.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 37.0161
#  Y_vtx           = 30.2093
#  Z_vtx           = -272.282
#  Px_p            = -1795.09
#  Py_p            = -3930.42
#  Pz_p            = -1223.91
#  En_p            = 4490.93
#  Mass            = 0.510999
#  PDG             = 11
# ******************************************************************************
# *Tree    :h1        : Generator Output Tree                                  *
# *Entries :      324 : Total =           17074 bytes  File  Size =       8222 *
# *        :          : Tree compression factor =   1.67                       *
# ******************************************************************************
# *Br    0 :X_vtx     : X_vtx/F                                                *
# *Entries :      324 : Total  Size=       1855 bytes  File Size  =       1032 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.32     *
# *............................................................................*
# *Br    1 :Y_vtx     : Y_vtx/F                                                *
# *Entries :      324 : Total  Size=       1855 bytes  File Size  =       1012 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.35     *
# *............................................................................*
# *Br    2 :Z_vtx     : Z_vtx/F                                                *
# *Entries :      324 : Total  Size=       1855 bytes  File Size  =       1019 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.34     *
# *............................................................................*
# *Br    3 :Px_p      : Px_p/F                                                 *
# *Entries :      324 : Total  Size=       1850 bytes  File Size  =       1002 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.36     *
# *............................................................................*
# *Br    4 :Py_p      : Py_p/F                                                 *
# *Entries :      324 : Total  Size=       1850 bytes  File Size  =        998 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.37     *
# *............................................................................*
# *Br    5 :Pz_p      : Pz_p/F                                                 *
# *Entries :      324 : Total  Size=       1850 bytes  File Size  =       1036 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.32     *
# *............................................................................*
# *Br    6 :En_p      : En_p/F                                                 *
# *Entries :      324 : Total  Size=       1850 bytes  File Size  =        994 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   1.37     *
# *............................................................................*
# *Br    7 :Mass      : Mass/F                                                 *
# *Entries :      324 : Total  Size=       1850 bytes  File Size  =        138 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   9.89     *
# *............................................................................*
# *Br    8 :PDG       : PDG/I                                                  *
# *Entries :      324 : Total  Size=       1845 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      64000 bytes  Compression=   9.28     *
# *............................................................................*

# %%
f = root.TFile("macros/gep_12Gev100.root")
f.ls()

myTree = f.Get("T")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		macros/gep_12Gev100.root
#  TFile*		macros/gep_12Gev100.root
#   KEY: TTree	T;1	Geant4 SBS Simulation
#   KEY: TH1F	Earm_CDET_Scint_esum;1
#   KEY: TH1F	Earm_ECalTF1_esum;1
#   KEY: TH1F	Harm_HCalScint_esum;1
#   KEY: TH1F	Earm_CDET_Scint_pulseshape;1
#   KEY: TH1F	Earm_ECalTF1_pulseshape;1
#   KEY: TH1F	Harm_HCalScint_pulseshape;1
#   KEY: G4SBSRunData	run_data;1
#   KEY: TH2F	field_x;1	Field x component
#   KEY: TH2F	field_y;1	Field y component
#   KEY: TH2F	field_z;1	Field z component
#   KEY: TH2F	field;1	Field total magnitude
#   KEY: TH2F	hBx_yzproj_Earm;1	Bx, Earm yz projection
#   KEY: TH2F	hBy_yzproj_Earm;1	By, Earm yz projection
#   KEY: TH2F	hBz_yzproj_Earm;1	Bz, Earm yz projection
#   KEY: TH2F	hBtot_yzproj_Earm;1	|B|, Earm yz projection
#   KEY: TH2F	hBx_yzproj_Harm;1	Bx, Harm yz projection
#   KEY: TH2F	hBy_yzproj_Harm;1	By, Harm yz projection
#   KEY: TH2F	hBz_yzproj_Harm;1	Bz, Harm yz projection
#   KEY: TH2F	hBtot_yzproj_Harm;1	|B|, Harm yz projection
# ======> EVENT:50
#  count           = 10.6417
#  rate            = 10.6417
#  solang          = 0.293866
#  sigma           = 6.07879e-36
#  W2              = 0.880354
#  xbj             = 1
#  Q2              = 8.44284
#  th              = 0.345321
#  ph              = 0.079128
#  Aperp           = -0.0227233
#  Apar            = -0.558807
#  Pt              = -0.0227233
#  Pl              = 0.558807
#  vx              = -0.000840202
#  vy              = 0.0018996
#  vz              = -0.116466
#  ep              = 6.50086
#  np              = 5.35585
#  epx             = 2.19364
#  epy             = 0.173942
#  epz             = 6.11709
#  npx             = -2.19364
#  npy             = -0.173942
#  npz             = 4.88291
#  nth             = 0.423402
#  nph             = -3.06246
#  pmperp          = 0
#  pmpar           = 0
#  pmparsm         = -nan
#  z               = 0
#  phperp          = 0
#  phih            = 0
#  phiS            = 0
#  thetaS          = 0
#  MX2             = 0
#  Sx              = 0.0197859
#  Sy              = -0.0933637
#  Sz              = 0.551066
#  s               = 0
#  t               = 0
#  u               = 0
#  costhetaCM      = 0
#  Egamma          = 0
#  nucl            = 1
#  fnucl           = 1
#  hadr            = -147598928
#  earmaccept      = 0
#  harmaccept      = 0
#  TargPol         = 1
#  TargThetaSpin   = 0
#  TargPhiSpin     = 0
#  BeamPol         = 1
#  BeamThetaSpin   = 0
#  BeamPhiSpin     = 0
#  Earm.CDET_Scint.det.esum = 0
#  Earm.CDET_Scint.hit.nhits = 0
#  Earm.CDET_Scint.hit.row = (vector<int>*)0x87d9c90
#  Earm.CDET_Scint.hit.col = (vector<int>*)0x8705e20
#  Earm.CDET_Scint.hit.cell = (vector<int>*)0x865b1c0
#  Earm.CDET_Scint.hit.plane = (vector<int>*)0x87d9c40
#  Earm.CDET_Scint.hit.wire = (vector<int>*)0x87d9bf0
#  Earm.CDET_Scint.hit.xcell = (vector<double>*)0x8921b00
#  Earm.CDET_Scint.hit.ycell = (vector<double>*)0x86fc1c0
#  Earm.CDET_Scint.hit.zcell = (vector<double>*)0x86fd8c0
#  Earm.CDET_Scint.hit.xcellg = (vector<double>*)0x8921900
#  Earm.CDET_Scint.hit.ycellg = (vector<double>*)0x87d8b10
#  Earm.CDET_Scint.hit.zcellg = (vector<double>*)0x8879740
#  Earm.CDET_Scint.hit.xhit = (vector<double>*)0x89218b0
#  Earm.CDET_Scint.hit.yhit = (vector<double>*)0x87dd420
#  Earm.CDET_Scint.hit.zhit = (vector<double>*)0x87dcce0
#  Earm.CDET_Scint.hit.xhitg = (vector<double>*)0x86fc7e0
#  Earm.CDET_Scint.hit.yhitg = (vector<double>*)0x87d9030
#  Earm.CDET_Scint.hit.zhitg = (vector<double>*)0x86f9840
#  Earm.CDET_Scint.hit.sumedep = (vector<double>*)0x8925b60
#  Earm.CDET_Scint.hit.tavg = (vector<double>*)0x898f450
#  Earm.CDET_Scint.hit.trms = (vector<double>*)0x8997830
#  Earm.CDET_Scint.hit.tmin = (vector<double>*)0x898f6f0
#  Earm.CDET_Scint.hit.tmax = (vector<double>*)0x8997ad0
#  Earm.CDET_Scint.hit.otridx = (vector<int>*)0x89b01e0
#  Earm.CDET_Scint.hit.ptridx = (vector<int>*)0x89b8450
#  Earm.CDET_Scint.hit.sdtridx = (vector<int>*)0x89c0830
#  Earm.ECalTF1.det.esum = 4.50257e-05
#  Earm.ECalTF1.hit.nhits = 2
#  Earm.ECalTF1.hit.row = (vector<int>*)0x89b86f0
#  Earm.ECalTF1.hit.col = (vector<int>*)0x89e0d80
#  Earm.ECalTF1.hit.cell = (vector<int>*)0x89e9180
#  Earm.ECalTF1.hit.plane = (vector<int>*)0x89f14e0
#  Earm.ECalTF1.hit.wire = (vector<int>*)0x89f9770
#  Earm.ECalTF1.hit.xcell = (vector<double>*)0x8a01b20
#  Earm.ECalTF1.hit.ycell = (vector<double>*)0x8a0a040
#  Earm.ECalTF1.hit.zcell = (vector<double>*)0x8a122a0
#  Earm.ECalTF1.hit.xcellg = (vector<double>*)0x8a1a5c0
#  Earm.ECalTF1.hit.ycellg = (vector<double>*)0x8a228e0
#  Earm.ECalTF1.hit.zcellg = (vector<double>*)0x8a2ac00
#  Earm.ECalTF1.hit.xhit = (vector<double>*)0x8a32f20
#  Earm.ECalTF1.hit.yhit = (vector<double>*)0x8a3b240
#  Earm.ECalTF1.hit.zhit = (vector<double>*)0x8a43560
#  Earm.ECalTF1.hit.xhitg = (vector<double>*)0x8a4b880
#  Earm.ECalTF1.hit.yhitg = (vector<double>*)0x8a53ba0
#  Earm.ECalTF1.hit.zhitg = (vector<double>*)0x8a5bec0
#  Earm.ECalTF1.hit.sumedep = (vector<double>*)0x8a641e0
#  Earm.ECalTF1.hit.tavg = (vector<double>*)0x8a6c500
#  Earm.ECalTF1.hit.trms = (vector<double>*)0x8a74820
#  Earm.ECalTF1.hit.tmin = (vector<double>*)0x8a7cb40
#  Earm.ECalTF1.hit.tmax = (vector<double>*)0x8a84e60
#  Earm.ECalTF1.hit.otridx = (vector<int>*)0x8a8d180
#  Earm.ECalTF1.hit.ptridx = (vector<int>*)0x8a953f0
#  Earm.ECalTF1.hit.sdtridx = (vector<int>*)0x8a9d680
#  Harm.FPP1.hit.nhits = 0
#  Harm.FPP1.hit.plane = (vector<int>*)0x8aa5ce0
#  Harm.FPP1.hit.strip = (vector<int>*)0x8ab5cc0
#  Harm.FPP1.hit.x = (vector<double>*)0x8abe0a0
#  Harm.FPP1.hit.y = (vector<double>*)0x8ac63c0
#  Harm.FPP1.hit.z = (vector<double>*)0x8ace600
#  Harm.FPP1.hit.polx = (vector<double>*)0x8ad69f0
#  Harm.FPP1.hit.poly = (vector<double>*)0x8adec60
#  Harm.FPP1.hit.polz = (vector<double>*)0x8ae7040
#  Harm.FPP1.hit.t = (vector<double>*)0x8adef00
#  Harm.FPP1.hit.trms = (vector<double>*)0x8af75e0
#  Harm.FPP1.hit.tmin = (vector<double>*)0x8af78b0
#  Harm.FPP1.hit.tmax = (vector<double>*)0x8b07c30
#  Harm.FPP1.hit.tx = (vector<double>*)0x8b10010
#  Harm.FPP1.hit.ty = (vector<double>*)0x8b07ed0
#  Harm.FPP1.hit.xin = (vector<double>*)0x8b102b0
#  Harm.FPP1.hit.yin = (vector<double>*)0x8b289c0
#  Harm.FPP1.hit.zin = (vector<double>*)0x8b30c30
#  Harm.FPP1.hit.xout = (vector<double>*)0x8b39010
#  Harm.FPP1.hit.yout = (vector<double>*)0x8b30ed0
#  Harm.FPP1.hit.zout = (vector<double>*)0x8b392b0
#  Harm.FPP1.hit.txp = (vector<double>*)0x8b519c0
#  Harm.FPP1.hit.typ = (vector<double>*)0x8b59c30
#  Harm.FPP1.hit.xg = (vector<double>*)0x8b62010
#  Harm.FPP1.hit.yg = (vector<double>*)0x8b59ed0
#  Harm.FPP1.hit.zg = (vector<double>*)0x8b622b0
#  Harm.FPP1.hit.trid = (vector<int>*)0x8b7a9c0
#  Harm.FPP1.hit.mid = (vector<int>*)0x8b82c30
#  Harm.FPP1.hit.pid = (vector<int>*)0x8b8b010
#  Harm.FPP1.hit.vx = (vector<double>*)0x8b82ed0
#  Harm.FPP1.hit.vy = (vector<double>*)0x8b8b2b0
#  Harm.FPP1.hit.vz = (vector<double>*)0x8ba39c0
#  Harm.FPP1.hit.p = (vector<double>*)0x8babc30
#  Harm.FPP1.hit.edep = (vector<double>*)0x8bb3fe0
#  Harm.FPP1.hit.beta = (vector<double>*)0x8bb42b0
#  Harm.FPP1.hit.otridx = (vector<int>*)0x8bc45a0
#  Harm.FPP1.hit.ptridx = (vector<int>*)0x8bcc980
#  Harm.FPP1.hit.sdtridx = (vector<int>*)0x8bc4840
#  Harm.FPP1.Track.ntracks = 0
#  Harm.FPP1.Track.TID = (vector<int>*)0x8bccc20
#  Harm.FPP1.Track.PID = (vector<int>*)0x8bed260
#  Harm.FPP1.Track.MID = (vector<int>*)0x8bf5610
#  Harm.FPP1.Track.NumHits = (vector<int>*)0x8bed500
#  Harm.FPP1.Track.NumPlanes = (vector<int>*)0x8bf58b0
#  Harm.FPP1.Track.NDF = (vector<int>*)0x8c0dfc0
#  Harm.FPP1.Track.Chi2fit = (vector<double>*)0x8c16230
#  Harm.FPP1.Track.Chi2true = (vector<double>*)0x8c1e610
#  Harm.FPP1.Track.X = (vector<double>*)0x8c164d0
#  Harm.FPP1.Track.Y = (vector<double>*)0x8c1e8b0
#  Harm.FPP1.Track.Xp = (vector<double>*)0x8c36fc0
#  Harm.FPP1.Track.Yp = (vector<double>*)0x8c3f230
#  Harm.FPP1.Track.T = (vector<double>*)0x8c47610
#  Harm.FPP1.Track.P = (vector<double>*)0x8c3f4d0
#  Harm.FPP1.Track.Sx = (vector<double>*)0x8c478b0
#  Harm.FPP1.Track.Sy = (vector<double>*)0x8c5ffc0
#  Harm.FPP1.Track.Sz = (vector<double>*)0x8c68230
#  Harm.FPP1.Track.Xfit = (vector<double>*)0x8c70610
#  Harm.FPP1.Track.Yfit = (vector<double>*)0x8c684d0
#  Harm.FPP1.Track.Xpfit = (vector<double>*)0x8c708b0
#  Harm.FPP1.Track.Ypfit = (vector<double>*)0x8c88fc0
#  Harm.FPP1.Track.otridx = (vector<int>*)0x8c91230
#  Harm.FPP1.Track.ptridx = (vector<int>*)0x8c99610
#  Harm.FPP1.Track.sdtridx = (vector<int>*)0x8c914d0
#  Harm.FPP2.hit.nhits = 0
#  Harm.FPP2.hit.plane = (vector<int>*)0x8c998b0
#  Harm.FPP2.hit.strip = (vector<int>*)0x8cb9ef0
#  Harm.FPP2.hit.x = (vector<double>*)0x8cc22a0
#  Harm.FPP2.hit.y = (vector<double>*)0x8cca5c0
#  Harm.FPP2.hit.z = (vector<double>*)0x8cd2800
#  Harm.FPP2.hit.polx = (vector<double>*)0x8cdabf0
#  Harm.FPP2.hit.poly = (vector<double>*)0x8ce2e60
#  Harm.FPP2.hit.polz = (vector<double>*)0x8ceb240
#  Harm.FPP2.hit.t = (vector<double>*)0x8ce3100
#  Harm.FPP2.hit.trms = (vector<double>*)0x8cfb7e0
#  Harm.FPP2.hit.tmin = (vector<double>*)0x8cfbab0
#  Harm.FPP2.hit.tmax = (vector<double>*)0x8d0be30
#  Harm.FPP2.hit.tx = (vector<double>*)0x8d14210
#  Harm.FPP2.hit.ty = (vector<double>*)0x8d0c0d0
#  Harm.FPP2.hit.xin = (vector<double>*)0x8d144b0
#  Harm.FPP2.hit.yin = (vector<double>*)0x8d2cbc0
#  Harm.FPP2.hit.zin = (vector<double>*)0x8d34e30
#  Harm.FPP2.hit.xout = (vector<double>*)0x8d3d210
#  Harm.FPP2.hit.yout = (vector<double>*)0x8d350d0
#  Harm.FPP2.hit.zout = (vector<double>*)0x8d3d4b0
#  Harm.FPP2.hit.txp = (vector<double>*)0x8d55bc0
#  Harm.FPP2.hit.typ = (vector<double>*)0x8d5de30
#  Harm.FPP2.hit.xg = (vector<double>*)0x8d66210
#  Harm.FPP2.hit.yg = (vector<double>*)0x8d5e0d0
#  Harm.FPP2.hit.zg = (vector<double>*)0x8d664b0
#  Harm.FPP2.hit.trid = (vector<int>*)0x8d7ebc0
#  Harm.FPP2.hit.mid = (vector<int>*)0x8d86e30
#  Harm.FPP2.hit.pid = (vector<int>*)0x8d8f210
#  Harm.FPP2.hit.vx = (vector<double>*)0x8d870d0
#  Harm.FPP2.hit.vy = (vector<double>*)0x8d8f4b0
#  Harm.FPP2.hit.vz = (vector<double>*)0x8da7bc0
#  Harm.FPP2.hit.p = (vector<double>*)0x8dafe30
#  Harm.FPP2.hit.edep = (vector<double>*)0x8db81e0
#  Harm.FPP2.hit.beta = (vector<double>*)0x8db84b0
#  Harm.FPP2.hit.otridx = (vector<int>*)0x8dc87a0
#  Harm.FPP2.hit.ptridx = (vector<int>*)0x8dd0b80
#  Harm.FPP2.hit.sdtridx = (vector<int>*)0x8dc8a40
#  Harm.FPP2.Track.ntracks = 0
#  Harm.FPP2.Track.TID = (vector<int>*)0x8dd0e20
#  Harm.FPP2.Track.PID = (vector<int>*)0x8df1460
#  Harm.FPP2.Track.MID = (vector<int>*)0x8df9810
#  Harm.FPP2.Track.NumHits = (vector<int>*)0x8df1700
#  Harm.FPP2.Track.NumPlanes = (vector<int>*)0x8df9ab0
#  Harm.FPP2.Track.NDF = (vector<int>*)0x8e121c0
#  Harm.FPP2.Track.Chi2fit = (vector<double>*)0x8e1a430
#  Harm.FPP2.Track.Chi2true = (vector<double>*)0x8e22810
#  Harm.FPP2.Track.X = (vector<double>*)0x8e1a6d0
#  Harm.FPP2.Track.Y = (vector<double>*)0x8e22ab0
#  Harm.FPP2.Track.Xp = (vector<double>*)0x8e3b1c0
#  Harm.FPP2.Track.Yp = (vector<double>*)0x8e43430
#  Harm.FPP2.Track.T = (vector<double>*)0x8e4b810
#  Harm.FPP2.Track.P = (vector<double>*)0x8e436d0
#  Harm.FPP2.Track.Sx = (vector<double>*)0x8e4bab0
#  Harm.FPP2.Track.Sy = (vector<double>*)0x8e641c0
#  Harm.FPP2.Track.Sz = (vector<double>*)0x8e6c430
#  Harm.FPP2.Track.Xfit = (vector<double>*)0x8e74810
#  Harm.FPP2.Track.Yfit = (vector<double>*)0x8e6c6d0
#  Harm.FPP2.Track.Xpfit = (vector<double>*)0x8e74ab0
#  Harm.FPP2.Track.Ypfit = (vector<double>*)0x8e8d1c0
#  Harm.FPP2.Track.otridx = (vector<int>*)0x8e95430
#  Harm.FPP2.Track.ptridx = (vector<int>*)0x8e9d810
#  Harm.FPP2.Track.sdtridx = (vector<int>*)0x8e956d0
#  Harm.FT.hit.nhits = 0
#  Harm.FT.hit.plane = (vector<int>*)0x8e9dab0
#  Harm.FT.hit.strip = (vector<int>*)0x8ebe0f0
#  Harm.FT.hit.x   = (vector<double>*)0x8ec64a0
#  Harm.FT.hit.y   = (vector<double>*)0x8ebe390
#  Harm.FT.hit.z   = (vector<double>*)0x8ed69c0
#  Harm.FT.hit.polx = (vector<double>*)0x8eded70
#  Harm.FT.hit.poly = (vector<double>*)0x8ed6c60
#  Harm.FT.hit.polz = (vector<double>*)0x8eef390
#  Harm.FT.hit.t   = (vector<double>*)0x8ef7600
#  Harm.FT.hit.trms = (vector<double>*)0x8eff9e0
#  Harm.FT.hit.tmin = (vector<double>*)0x8ef78a0
#  Harm.FT.hit.tmax = (vector<double>*)0x8f10000
#  Harm.FT.hit.tx  = (vector<double>*)0x8f18270
#  Harm.FT.hit.ty  = (vector<double>*)0x8f20650
#  Harm.FT.hit.xin = (vector<double>*)0x8f18510
#  Harm.FT.hit.yin = (vector<double>*)0x8f30be0
#  Harm.FT.hit.zin = (vector<double>*)0x8f38e20
#  Harm.FT.hit.xout = (vector<double>*)0x8f41210
#  Harm.FT.hit.yout = (vector<double>*)0x8f49480
#  Harm.FT.hit.zout = (vector<double>*)0x8f51860
#  Harm.FT.hit.txp = (vector<double>*)0x8f49720
#  Harm.FT.hit.typ = (vector<double>*)0x8f61e00
#  Harm.FT.hit.xg  = (vector<double>*)0x8f6a1d0
#  Harm.FT.hit.yg  = (vector<double>*)0x8f72410
#  Harm.FT.hit.zg  = (vector<double>*)0x8f7a7c0
#  Harm.FT.hit.trid = (vector<int>*)0x8f726b0
#  Harm.FT.hit.mid = (vector<int>*)0x8f8ad80
#  Harm.FT.hit.pid = (vector<int>*)0x8f92fc0
#  Harm.FT.hit.vx  = (vector<double>*)0x8f9b3b0
#  Harm.FT.hit.vy  = (vector<double>*)0x8fa35f0
#  Harm.FT.hit.vz  = (vector<double>*)0x8fab9a0
#  Harm.FT.hit.p   = (vector<double>*)0x8fa3890
#  Harm.FT.hit.edep = (vector<double>*)0x8fbbf60
#  Harm.FT.hit.beta = (vector<double>*)0x8fc41d0
#  Harm.FT.hit.otridx = (vector<int>*)0x8fcc550
#  Harm.FT.hit.ptridx = (vector<int>*)0x8fc4470
#  Harm.FT.hit.sdtridx = (vector<int>*)0x8fcc7f0
#  Harm.FT.Track.ntracks = 0
#  Harm.FT.Track.TID = (vector<int>*)0x8fecec0
#  Harm.FT.Track.PID = (vector<int>*)0x8ff5130
#  Harm.FT.Track.MID = (vector<int>*)0x8ffd510
#  Harm.FT.Track.NumHits = (vector<int>*)0x8ff53d0
#  Harm.FT.Track.NumPlanes = (vector<int>*)0x8ffd7b0
#  Harm.FT.Track.NDF = (vector<int>*)0x9015ec0
#  Harm.FT.Track.Chi2fit = (vector<double>*)0x901e130
#  Harm.FT.Track.Chi2true = (vector<double>*)0x9026510
#  Harm.FT.Track.X = (vector<double>*)0x901e3d0
#  Harm.FT.Track.Y = (vector<double>*)0x9036ab0
#  Harm.FT.Track.Xp = (vector<double>*)0x903ee80
#  Harm.FT.Track.Yp = (vector<double>*)0x90470f0
#  Harm.FT.Track.T = (vector<double>*)0x904f4d0
#  Harm.FT.Track.P = (vector<double>*)0x90577f0
#  Harm.FT.Track.Sx = (vector<double>*)0x905fa30
#  Harm.FT.Track.Sy = (vector<double>*)0x905fd00
#  Harm.FT.Track.Sz = (vector<double>*)0x90700a0
#  Harm.FT.Track.Xfit = (vector<double>*)0x9078480
#  Harm.FT.Track.Yfit = (vector<double>*)0x9070340
#  Harm.FT.Track.Xpfit = (vector<double>*)0x9078720
#  Harm.FT.Track.Ypfit = (vector<double>*)0x9090e30
#  Harm.FT.Track.otridx = (vector<int>*)0x90990a0
#  Harm.FT.Track.ptridx = (vector<int>*)0x90a1480
#  Harm.FT.Track.sdtridx = (vector<int>*)0x9099340
#  Harm.HCalScint.det.esum = 0
#  Harm.HCalScint.hit.nhits = 0
#  Harm.HCalScint.hit.row = (vector<int>*)0x90a1720
#  Harm.HCalScint.hit.col = (vector<int>*)0x90c9ce0
#  Harm.HCalScint.hit.cell = (vector<int>*)0x90d20c0
#  Harm.HCalScint.hit.plane = (vector<int>*)0x90c9f80
#  Harm.HCalScint.hit.wire = (vector<int>*)0x90d2360
#  Harm.HCalScint.hit.xcell = (vector<double>*)0x90eaa70
#  Harm.HCalScint.hit.ycell = (vector<double>*)0x90f2d60
#  Harm.HCalScint.hit.zcell = (vector<double>*)0x90faed0
#  Harm.HCalScint.hit.xcellg = (vector<double>*)0x9103170
#  Harm.HCalScint.hit.ycellg = (vector<double>*)0x910b410
#  Harm.HCalScint.hit.zcellg = (vector<double>*)0x91136b0
#  Harm.HCalScint.hit.xhit = (vector<double>*)0x911b950
#  Harm.HCalScint.hit.yhit = (vector<double>*)0x9123bf0
#  Harm.HCalScint.hit.zhit = (vector<double>*)0x912be90
#  Harm.HCalScint.hit.xhitg = (vector<double>*)0x9134130
#  Harm.HCalScint.hit.yhitg = (vector<double>*)0x913c3d0
#  Harm.HCalScint.hit.zhitg = (vector<double>*)0x9144670
#  Harm.HCalScint.hit.sumedep = (vector<double>*)0x914c910
#  Harm.HCalScint.hit.tavg = (vector<double>*)0x9154bb0
#  Harm.HCalScint.hit.trms = (vector<double>*)0x915ce50
#  Harm.HCalScint.hit.tmin = (vector<double>*)0x91650f0
#  Harm.HCalScint.hit.tmax = (vector<double>*)0x916d390
#  Harm.HCalScint.hit.otridx = (vector<int>*)0x9175630
#  Harm.HCalScint.hit.ptridx = (vector<int>*)0x90f2be0
#  Harm.HCalScint.hit.sdtridx = (vector<int>*)0x9185d80
#  OTrack.ntracks  = 1
#  OTrack.TID      = (vector<int>*)0x918e240
#  OTrack.MID      = (vector<int>*)0x919e2a0
#  OTrack.PID      = (vector<int>*)0x91a6640
#  OTrack.posx     = (vector<double>*)0x91ae880
#  OTrack.posy     = (vector<double>*)0x91b6c20
#  OTrack.posz     = (vector<double>*)0x91bee60
#  OTrack.momx     = (vector<double>*)0x91c7200
#  OTrack.momy     = (vector<double>*)0x91cf440
#  OTrack.momz     = (vector<double>*)0x91d77e0
#  OTrack.polx     = (vector<double>*)0x91dfa20
#  OTrack.poly     = (vector<double>*)0x91e7dc0
#  OTrack.polz     = (vector<double>*)0x91f0000
#  OTrack.Etot     = (vector<double>*)0x91f83a0
#  OTrack.T        = (vector<double>*)0x92005e0
#  PTrack.ntracks  = 1
#  PTrack.TID      = (vector<int>*)0x9200880
#  PTrack.PID      = (vector<int>*)0x9218af0
#  PTrack.posx     = (vector<double>*)0x9220e70
#  PTrack.posy     = (vector<double>*)0x92290d0
#  PTrack.posz     = (vector<double>*)0x9231450
#  PTrack.momx     = (vector<double>*)0x92396b0
#  PTrack.momy     = (vector<double>*)0x9241a30
#  PTrack.momz     = (vector<double>*)0x9249c90
#  PTrack.polx     = (vector<double>*)0x9252010
#  PTrack.poly     = (vector<double>*)0x925a270
#  PTrack.polz     = (vector<double>*)0x92625f0
#  PTrack.Etot     = (vector<double>*)0x926a850
#  PTrack.T        = (vector<double>*)0x9272bd0
#  SDTrack.ntracks = 1
#  SDTrack.TID     = (vector<int>*)0x9282ea0
#  SDTrack.MID     = (vector<int>*)0x928b100
#  SDTrack.PID     = (vector<int>*)0x9293450
#  SDTrack.posx    = (vector<double>*)0x929b6b0
#  SDTrack.posy    = (vector<double>*)0x92a3a30
#  SDTrack.posz    = (vector<double>*)0x92abc90
#  SDTrack.momx    = (vector<double>*)0x92b4010
#  SDTrack.momy    = (vector<double>*)0x92bc270
#  SDTrack.momz    = (vector<double>*)0x92c45f0
#  SDTrack.polx    = (vector<double>*)0x92cc850
#  SDTrack.poly    = (vector<double>*)0x92d4bd0
#  SDTrack.polz    = (vector<double>*)0x92dce30
#  SDTrack.Etot    = (vector<double>*)0x92e51b0
#  SDTrack.T       = (vector<double>*)0x92ed410
#  SDTrack.vx      = (vector<double>*)0x92f5790
#  SDTrack.vy      = (vector<double>*)0x92fd9f0
#  SDTrack.vz      = (vector<double>*)0x9305d70
#  SDTrack.vnx     = (vector<double>*)0x930dfd0
#  SDTrack.vny     = (vector<double>*)0x9316350
#  SDTrack.vnz     = (vector<double>*)0x931e5b0
#  SDTrack.vEkin   = (vector<double>*)0x9326930
# Warning in <TClass::Init>: no dictionary for class G4SBSRunData is available
# Warning in <TClass::Init>: no dictionary for class G4SBSTextFile is available
# Warning in <TClass::Init>: no dictionary for class filedata_t is available

# %%
f = root.TFile("batch/data/AnaBarMC_Gen_7004.root")
f.ls()

myTree = f.Get("h1")

entries = myTree.GetEntriesFast()

myTree.Show(50)
# Out:
# TFile**		batch/data/AnaBarMC_Gen_7004.root	fROOTfile
#  TFile*		batch/data/AnaBarMC_Gen_7004.root	fROOTfile
#   KEY: TTree	h1;1	Generator Output Tree
# ======> EVENT:50
#  X_vtx           = 1.20794
#  Y_vtx           = 25
#  Z_vtx           = -7.44103
#  Px_p            = 64.5141
#  Py_p            = -2987.89
#  Pz_p            = 445.626
#  En_p            = 3023.48
#  Mass            = 105.658
#  PDG             = 13
